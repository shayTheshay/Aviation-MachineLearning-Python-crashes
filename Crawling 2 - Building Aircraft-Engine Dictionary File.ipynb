# %% [markdown]
# <h1>Crawling Step 2 - Building Aircraft-Engine Dictionary File</h1>

# %% [markdown]
# <h2>Preliminary Steps</h2>

# %% [markdown]
# Let's begin with importing the necessary libraries:

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import json

# %% [markdown]
# We also need to declare a necessary variable that will be used throughout this step:

# %%
aircrafts_url = "https://aviation-safety.net/database/type/" # The main page of the aircrafts database, to be used in the following section

# %% [markdown]
# <h2>The Process</h2>

# %% [markdown]
# Before we start accessing each individual page, we found out that each page refers to the aircraft model and engine model in a very specific way. The accident page provides a hyperlink to an info page of the aircraft that provides more general details about the model, omitting the sub-model name. Instead of scraping the specific aircraft model mentioned in the accident page, we looked for the more general aircraft model as mentioned in the aircraft models list on the website.
#
# In this section, we scraped data from the aircraft model list to create a Python dictionary object.<br>
# The <b>Key</b> - The aircraft model name<br>
# The <b>Value</b> - The model's appropriate engine type and the amount of engines
#
# We will use this dictionary while scraping the accident page in order to match the aircraft model type to the type and amount of engine it bears. While this data is often mentioned in accident pages, it might be missing in some, and this dictionary will prevent missing data about the engines as long as the aricraft model is known.
#
# The aircraft model involved in an individual itself will be scraped differently, but will be used to compare with the content of the dictionary.

# %%
response_aircrafts = requests.get(aircrafts_url, headers={'User-Agent': 'Mozilla/5.0'}) # Accesses the desired page that presents aircrafts and their engines
aircrafts_soup = BeautifulSoup(response_aircrafts.content, "html.parser") # Creates a BeautifulSoup object for the response we recevied

ae_table = aircrafts_soup.find("table") # Finds the table object (there's only one in the page) 
ae_rows = ae_table.find_all("tr") # Creates an array with all the HTML codes of the table's rows
ae_size = len(ae_rows) # Calculates the number of rows found in the table, for looping purposes
ae_dict = {} # Creates an empty dictionary, where scraped data will be appended
for i in range (1,ae_size-1): 
    ae_row = ae_table.select('tr')[i] # Runs on every row HTML code in the array
    ae_dict[ae_row.select('td')[0].text] = ae_row.select('td')[1].text # Scrapes the text from the row's first cell (used as the key), and the row's second cell (used as the value)

# %% [markdown]
# The dictionary below shows the aircraft and its appropriate engine type and number:

# %%
ae_dict
# Out:
# {'Aero Modifications AMI DC-3-65TP': 'turboprop (2)',
#  'Aero Spacelines Mini Guppy Turbine': 'turboprop (4)',
#  'Aeromarine 75': 'piston (2)',
#  'Aérospatiale SN.601 Corvette': 'jet (2)',
#  'Airbus A220 / Bombardier Cseries': 'jet (2)',
#  'Airbus A220-100': 'jet (2)',
#  'Airbus A220-300': 'jet (2)',
#  'Airbus A300': 'jet (2)',
#  'Airbus A310': 'jet (2)',
#  'Airbus A318': 'jet (2)',
#  'Airbus A319': 'jet (2)',
#  'Airbus A319/320/321': 'jet (2)',
#  'Airbus A319neo': 'jet (2)',
#  'Airbus A320': 'jet (2)',
#  'Airbus A320neo': 'jet (2)',
#  'Airbus A321': 'jet (2)',
#  'Airbus A321neo': 'jet (2)',
#  'Airbus A330': 'jet (2)',
#  'Airbus A330neo': 'jet (2)',
#  'Airbus A340': 'jet (4)',
#  'Airbus A350 XWB': 'jet (2)',
#  'Airbus A380': 'jet (4)',
#  'Airbus Military A400M': 'turboprop (4)',
#  'Airspeed AS.57 Ambassador': 'piston (2)',
#  'Alenia C-27J': 'turboprop (2)',
#  'Alenia G-222': 'turboprop (2)',
#  'all models BAe-125/HS-125/DH-125': 'jet (2)',
#  'Antonov An-10': 'turboprop (4)',
#  'Antonov An-12': 'turboprop (4)',
#  'Antonov An-124': 'jet (4)',
#  'Antonov An-140': 'turboprop (2)',
#  'Antonov An-148': 'jet (2)',
#  'Antonov An-178': 'jet (2)',
#  'Antonov An-2': 'piston (1)',
#  'Antonov An-22': 'turboprop (4)',
#  'Antonov An-225': 'jet (6)',
#  'Antonov An-24': 'turboprop (2)',
#  'Antonov An-26': 'turboprop (2)',
#  'Antonov An-28 / PZL M-28': 'turboprop (2)',
#  'Antonov An-30': 'turboprop (2)',
#  'Antonov An-32': 'turboprop (2)',
#  'Antonov An-38': 'turboprop (2)',
#  'Antonov An-70': 'turboprop (4)',
#  'Antonov An-72 / An-74': 'jet (2)',
#  'Antonov An-8': 'turboprop (2)',
#  'Armstrong Whitworth Argosy': 'piston (3)',
#  'Armstrong Whitworth AW-650 Argosy': 'turboprop (4)',
#  'Armstrong Whitworth AW.15 Atalanta': 'piston (4)',
#  'Armstrong Whitworth AW.27 Ensign': 'piston (4)',
#  'ATECO Westwind II': 'turboprop (2)',
#  'ATR 42': 'turboprop (2)',
#  'ATR 72': 'turboprop (2)',
#  'Avcen Jetpod': 'jet (2)',
#  'Avia 14': 'piston (2)',
#  'Aviation Traders ATL-98 Carvair': 'piston (4)',
#  'AVIC AG600': 'turboprop (4)',
#  'Avro 642 Eighteen': 'piston (2)',
#  'Avro 685 York': 'piston (4)',
#  'Avro 691 Lancastrian': 'piston (4)',
#  'Avro Canada C102 Jetliner': 'jet (4)',
#  'Avro Shackleton': 'piston (4)',
#  'Avro Tudor': 'piston (4)',
#  'Baade 152': 'jet (4)',
#  'BAC One-Eleven': 'jet (2)',
#  'BAC/Aérospatiale Concorde': 'jet (4)',
#  'BAe-125-600, -700': 'jet (2)',
#  'BAe-125-800, Hawker 750, 800, 850': 'jet (2)',
#  'Basler Turbo-67 (BT-67)': 'turboprop (2)',
#  'Beechcraft (Super) King Air': 'turboprop (2)',
#  'Beechcraft 100 King Air': 'turboprop (2)',
#  'Beechcraft 1900': 'turboprop (2)',
#  'Beechcraft 34 Twin Quad': 'piston (4)',
#  'Beechcraft 99': 'turboprop (2)',
#  'Beechcraft Beechjet 400': 'jet (2)',
#  'Beechcraft Super King Air': 'turboprop (2)',
#  'Beriev Be-200': 'jet (2)',
#  'Beriev Be-30': 'turboprop (2)',
#  'Blackburn Beverley': 'piston (4)',
#  'Blériot 155': 'piston (4)',
#  'Bloch 220': 'piston (2)',
#  'Boeing 314': 'piston (4)',
#  'Boeing 377 Stratocruiser': 'piston (4)',
#  'Boeing 707': 'jet (4)',
#  'Boeing 717': 'jet (2)',
#  'Boeing 720': 'jet (4)',
#  'Boeing 727': 'jet (3)',
#  'Boeing 737': 'jet (2)',
#  'Boeing 737-100': 'jet (2)',
#  'Boeing 737-200': 'jet (2)',
#  'Boeing 737-300': 'jet (2)',
#  'Boeing 737-400': 'jet (2)',
#  'Boeing 737-500': 'jet (2)',
#  'Boeing 737-600': 'jet (2)',
#  'Boeing 737-700': 'jet (2)',
#  'Boeing 737-8 MAX': 'jet (2)',
#  'Boeing 737-800': 'jet (2)',
#  'Boeing 737-9 MAX': 'jet (2)',
#  'Boeing 737-900': 'jet (2)',
#  'Boeing 747': 'jet (4)',
#  'Boeing 757': 'jet (2)',
#  'Boeing 767': 'jet (2)',
#  'Boeing 777': 'jet (2)',
#  'Boeing 777X': 'jet (2)',
#  'Boeing 787': 'jet (2)',
#  'Boeing 80': 'piston (3)',
#  'Boeing B-17 Flying Fortress': 'piston (4)',
#  'Boeing C-135': 'jet (4)',
#  'Boeing C-97 Stratofreighter': 'piston (4)',
#  'Boeing S.307 Stratoliner': 'piston (4)',
#  'Bombardier BD-100 Challenger 300': 'jet (2)',
#  'Bombardier BD-700 Global Express': 'jet (2)',
#  'Bombardier CRJ100 / 200 / 440': 'jet (2)',
#  'Bombardier CRJ1000': 'jet (2)',
#  'Bombardier CRJ700': 'jet (2)',
#  'Bombardier CRJ900': 'jet (2)',
#  'Boulton Paul P.71A': 'piston (2)',
#  'Breda-Zappata BZ.308': 'piston (4)',
#  'Breguet 1150 Atlantic': 'turboprop (2)',
#  'Breguet 730': 'piston (4)',
#  'Breguet Br.763 Provence': 'piston (4)',
#  'Bristol 170': 'piston (2)',
#  'Bristol 175 Britannia': 'turboprop (4)',
#  'British Aerospace ATP': 'turboprop (2)',
#  'British Aerospace BAe-146': 'jet (4)',
#  'British Aerospace Jetstream 31': 'turboprop (2)',
#  'British Aerospace Jetstream 41': 'turboprop (2)',
#  'Britten-Norman BN-2 Islander': 'piston (2)',
#  'Britten-Norman BN-2A Trislander': 'piston (3)',
#  'Budd C-93 Conestoga': 'piston (2)',
#  'Canadair Argonaut / North Star': 'piston (4)',
#  'Canadair CL-215': 'piston (2)',
#  'Canadair CL-415': 'turboprop (2)',
#  'Canadair CL-44': 'turboprop (4)',
#  'Canadair CL-600 Challenger': 'jet (2)',
#  'Canadair CP-107 Argus': 'piston (4)',
#  'Canadair Regional Jet series': 'jet (2)',
#  'CANT Z.506': 'piston (3)',
#  'Caproni Ca.133': 'piston (3)',
#  'Caproni Ca.48': 'piston (3)',
#  'Caproni Ca.60 Noviplano': 'piston (8)',
#  'Carstedt Jet Liner 600': 'turboprop (2)',
#  'CASA C-207 Azor': 'piston (2)',
#  'CASA C-295': 'turboprop (2)',
#  'CASA/Nurtanio 212 Aviocar': 'turboprop (2)',
#  'CASA/Nurtanio CN.235': 'turboprop (2)',
#  'Cessna 208 Caravan': 'turboprop (1)',
#  'Cessna 408 SkyCourier': 'turboprop (1)',
#  'Cessna 500 Citation I': 'jet (2)',
#  'Cessna 510 Citation Mustang': 'jet (2)',
#  'Cessna 525\xa0CitationJet': 'jet (2)',
#  'Cessna 550 Citation Bravo': 'jet (2)',
#  'Cessna 550 Citation II': 'jet (2)',
#  'Cessna 560 Citation Excel': 'jet (2)',
#  'Cessna 560 Citation V': 'jet (2)',
#  'Cessna 650 Citation III': 'jet (2)',
#  'Cessna 650 Citation VII': 'jet (2)',
#  'Cessna 680 Citation Sovereign': 'jet (2)',
#  'Cessna 680A Citation Latitude': 'jet (2)',
#  'Cessna 700 Citation Longitude': 'jet (2)',
#  'Cessna 750 Citation X': 'jet (2)',
#  'Cessna S550 Citation S/II': 'jet (2)',
#  'Chase YC-122 Avitruc': 'piston (2)',
#  'Cirrus Vision SF50': 'jet (1)',
#  'Comac ARJ21': 'jet (2)',
#  'Comac C919': 'jet (2)',
#  'Consolidated 16 Commodore': 'piston (2)',
#  'Consolidated B-24 Liberator': 'piston (4)',
#  'Consolidated C-87 Liberator Express': 'piston (4)',
#  'Consolidated Liberator': 'piston (4)',
#  'Consolidated PB4Y-2 Privateer': 'piston (4)',
#  'Consolidated PBY-5A Catalina': 'piston (2)',
#  'Convair CV-240': 'piston (2)',
#  'Convair CV-340': 'piston (2)',
#  'Convair CV-340/440': 'piston (2)',
#  'Convair CV-440': 'piston (2)',
#  'Convair CV-580': 'turboprop (2)',
#  'Convair CV-600': 'turboprop (2)',
#  'Convair CV-640': 'turboprop (2)',
#  'Convair CV-880': 'jet (4)',
#  'Convair CV-990': 'jet (4)',
#  'Curtiss C-46': 'piston (2)',
#  'Curtiss Condor 18': 'piston (2)',
#  'Curtiss T-32 Condor': 'piston (2)',
#  'Dassault Falcon 10': 'jet (2)',
#  'Dassault Falcon 20': 'jet (2)',
#  'Dassault Falcon 2000': 'jet (3)',
#  'Dassault Falcon 50': 'jet (3)',
#  'Dassault Falcon 7X': 'jet (3)',
#  'Dassault Falcon 900': 'jet (3)',
#  'Dassault Mercure': 'jet (2)',
#  'de Havilland Canada DHC-3 (Turbine)Otter': 'piston (1)',
#  'de Havilland Canada DHC-3 Otter': 'piston (1)',
#  'de Havilland Canada DHC-3 Turbine Otter': 'turboprop (1)',
#  'de Havilland Canada DHC-4 Caribou': 'piston (2)',
#  'de Havilland Canada DHC-5 Buffalo': 'turboprop (2)',
#  'de Havilland Canada DHC-6 Twin Otter': 'turboprop (2)',
#  'de Havilland Canada DHC-7': 'turboprop (4)',
#  'de Havilland Canada DHC-8': 'turboprop (2)',
#  'de Havilland Canada DHC-8-100': 'turboprop (2)',
#  'de Havilland Canada DHC-8-300': 'turboprop (2)',
#  'de Havilland Canada DHC-8-400': 'turboprop (2)',
#  'de Havilland DH-106 Comet': 'jet (4)',
#  'de Havilland DH-114 Heron': 'piston (4)',
#  'de Havilland DH.66 Hercules': 'piston (3)',
#  'de Havilland DH.86 Express': 'piston (4)',
#  'de Havilland DH.91 Albatross': 'piston (4)',
#  'de Havilland DH.95 Flamingo': 'piston (2)',
#  'Dewoitine D.338': 'piston (3)',
#  'Diamond D-Jet': 'jet (2)',
#  'Dornier 228': 'turboprop (2)',
#  'Dornier 328': 'turboprop (2)',
#  'Dornier 328JET': 'jet (2)',
#  'Dornier Do R Superwal': 'piston (4)',
#  'Dornier Do-128-6 Turbo Skyservant': 'turboprop (2)',
#  'Dornier Do-28 (Turbo) Skyservant series': 'piston (2)',
#  'Dornier Do-28D Skyservant': 'piston (2)',
#  'Dornier Seastar': 'turboprop (2)',
#  'Douglas C-124 Globemaster': 'piston (4)',
#  'Douglas C-133 Cargomaster': 'turboprop (4)',
#  'Douglas C-74 Globemaster I': 'piston (4)',
#  'Douglas DC-1': 'piston (2)',
#  'Douglas DC-2': 'piston (2)',
#  'Douglas DC-3': 'piston (2)',
#  'Douglas DC-4': 'piston (4)',
#  'Douglas DC-5': 'piston (2)',
#  'Douglas DC-6': 'piston (4)',
#  'Douglas DC-7': 'piston (4)',
#  'Eclipse 500': 'jet (2)',
#  'Embraer E190-E2': 'jet (2)',
#  'Embraer EMB-110 Bandeirante': 'turboprop (2)',
#  'Embraer EMB-120 Brasilia': 'turboprop (2)',
#  'Embraer EMB-500 Phenom 100': 'jet (2)',
#  'Embraer EMB-505 Phenom 300': 'jet (2)',
#  'Embraer ERJ-135': 'jet (2)',
#  'Embraer ERJ-135/140/145': 'jet (2)',
#  'Embraer ERJ-140': 'jet (2)',
#  'Embraer ERJ-145': 'jet (2)',
#  'Embraer ERJ-170': 'jet (2)',
#  'Embraer ERJ-170/190': 'jet (2)',
#  'Embraer ERJ-190': 'jet (2)',
#  'Embraer KC-390': 'jet (2)',
#  'Embraer Legacy': 'jet (2)',
#  'Epic Elite': 'jet (2)',
#  'Epic Victory': 'jet (1)',
#  'Excel-Jet Sport-Jet': 'jet (1)',
#  'Fairchild C-119 Flying Boxcar': 'piston (2)',
#  'Fairchild C-123 Provider': 'piston (2)',
#  'Fairchild C-82 Packet': 'piston (2)',
#  'Fairchild F-27': 'turboprop (2)',
#  'Fairchild F-27/FH227': 'turboprop (2)',
#  'Fairchild FH-227': 'turboprop (2)',
#  'Farman F.180': 'piston (2)',
#  'Farman F.220': 'piston (4)',
#  'Farman F.60 Goliath': 'piston (2)',
#  'Felixstowe Fury': 'piston (5)',
#  'Fiat G.12': 'piston (3)',
#  'Fiat G.18': 'piston (2)',
#  'Fiat G.212': 'piston (3)',
#  'FMA IA 50 Guaraní II': 'turboprop (2)',
#  'Focke-Wulf FW.200 Condor': 'piston (4)',
#  'Fokker 100': 'jet (2)',
#  'Fokker 50': 'turboprop (2)',
#  'Fokker 70': 'jet (2)',
#  'Fokker F-27 Friendship': 'turboprop (2)',
#  'Fokker F-28 Fellowship': 'jet (2)',
#  'Fokker F.10': 'piston (3)',
#  'Fokker F.32': 'piston (4)',
#  'Fokker F.IX': 'piston (3)',
#  'Fokker F.VIII': 'piston (2)',
#  'Fokker F.XII': 'piston (3)',
#  'Fokker F.XVIII': 'piston (3)',
#  'Fokker F.XX': 'piston (3)',
#  'Fokker F.XXII': 'piston (4)',
#  'Fokker F.XXXVI': 'piston (4)',
#  'Ford Tri-Motor': 'piston (3)',
#  'GAF Nomad': 'turboprop (2)',
#  'Grob SPn': 'jet (2)',
#  'Grumman C-2 Greyhound': 'turboprop (2)',
#  'Grumman G-111 Albatross': 'piston (2)',
#  'Grumman G-159 Gulfstream I': 'turboprop (2)',
#  'Grumman G-73 (Turbo) Mallard': 'piston (2)',
#  'Grumman G-73 Mallard': 'piston (2)',
#  'Grumman G-73T Turbo Mallard': 'turboprop (2)',
#  'Gulfstream': 'jet (2)',
#  'Gulfstream G200': 'jet (2)',
#  'Gulfstream G280': 'jet (2)',
#  'Gulfstream G650': 'jet (2)',
#  'Handley Page Hastings': 'piston (4)',
#  'Handley Page Hermes': 'piston (4)',
#  'Handley Page HP-137 Jetstream': 'turboprop (2)',
#  'Handley Page HP.42': 'piston (4)',
#  'Handley Page HPR.7 Herald': 'turboprop (2)',
#  'Handley Page Type O': 'piston (2)',
#  'Handley Page Type W': 'piston (3)',
#  'Hawker 1000': 'jet (2)',
#  'Hawker 4000 Horizon': 'jet (2)',
#  'Hawker Siddeley HS-121 Trident': 'jet (3)',
#  'Hawker Siddeley HS-125 Srs. 1, 2, 3, 400': 'jet (2)',
#  'Hawker Siddeley HS-748': 'turboprop (2)',
#  'Hawker Siddeley HS-801 Nimrod': 'jet (4)',
#  'Hindustan Aeronautics Ltd. HAL-748': 'turboprop (2)',
#  'Honda HA-420 HondaJet': 'jet (2)',
#  'Howard 250': 'piston (2)',
#  'Howard 350': 'piston (2)',
#  'Howard 500': 'piston (2)',
#  'Hurel-Dubois HD.31': 'piston (2)',
#  'IAI 1124 Westwind': 'jet (2)',
#  'IAI 1125 Astra': 'jet (2)',
#  'IAI Arava': 'turboprop (2)',
#  'Ilyushin Il-112': 'turboprop (2)',
#  'Ilyushin Il-114': 'turboprop (2)',
#  'Ilyushin Il-12': 'piston (2)',
#  'Ilyushin Il-14': 'piston (2)',
#  'Ilyushin Il-18': 'turboprop (4)',
#  'Ilyushin Il-38': 'turboprop (4)',
#  'Ilyushin Il-62': 'jet (4)',
#  'Ilyushin Il-76': 'jet (4)',
#  'Ilyushin Il-86': 'jet (4)',
#  'Ilyushin Il-96': 'jet (4)',
#  'Irkut MC-21': 'jet (2)',
#  'Junkers F./G.24 series': 'piston (3)',
#  'Junkers F.24': 'piston (1)',
#  'Junkers G.24': 'piston (3)',
#  'Junkers G.31': 'piston (3)',
#  'Junkers G.38': 'piston (4)',
#  'Junkers Ju-252': 'piston (3)',
#  'Junkers Ju-352 Herkules': 'piston (3)',
#  'Junkers Ju-52/3m': 'piston (3)',
#  'Junkers Ju-90': 'piston (4)',
#  'Kalinin K-7': 'piston (7)',
#  'Kawasaki C-1': 'jet (2)',
#  'Kawasaki C-2': 'jet (2)',
#  'Kawasaki Ki-56': 'piston (2)',
#  'Kawasaki P-1': 'jet (4)',
#  'Lascurain Aura': 'turboprop (2)',
#  'Latécoère 631': 'piston (6)',
#  'Learjet 23': 'jet (2)',
#  'Learjet 24': 'jet (2)',
#  'Learjet 25': 'jet (2)',
#  'Learjet 28 / 29': 'jet (2)',
#  'Learjet 31': 'jet (2)',
#  'Learjet 35 / 36': 'jet (2)',
#  'Learjet 45': 'jet (2)',
#  'Learjet 55': 'jet (2)',
#  'Learjet 60': 'jet (2)',
#  'Let L-410': 'turboprop (2)',
#  'Let L-610': 'turboprop (2)',
#  'Lioré et Olivier 21': 'piston (2)',
#  'Lioré et Olivier H.242': 'piston (4)',
#  'Lisunov Li-2': 'piston (2)',
#  'Lockheed 18 Lodestar': 'piston (2)',
#  'Lockheed C-130 & L-100 Hercules': 'turboprop (4)',
#  'Lockheed C-130 Hercules': 'turboprop (4)',
#  'Lockheed C-141 Starlifter': 'jet (4)',
#  'Lockheed C-5 Galaxy': 'jet (4)',
#  'Lockheed Hudson': 'piston (2)',
#  'Lockheed L-049/149 Constellation': 'piston (4)',
#  'Lockheed L-100 Hercules': 'turboprop (4)',
#  'Lockheed L-1011 TriStar': 'jet (3)',
#  'Lockheed L-1049 Super Constellation': 'piston (4)',
#  'Lockheed L-1329 Jetstar': 'jet (4)',
#  'Lockheed L-14 Super Electra': 'piston (2)',
#  'Lockheed L-1649 Starliner': 'piston (4)',
#  'Lockheed L-188 Electra': 'turboprop (4)',
#  'Lockheed L-649/749 Constellation': 'piston (4)',
#  'Lockheed P-2 Neptune': 'piston (2)',
#  'Lockheed P-3 Orion': 'turboprop (4)',
#  'Lockheed Ventura': 'piston (2)',
#  'Macchi M.C.100': 'piston (3)',
#  'Macchi M.C.94': 'piston (2)',
#  'Martin 2-0-2': 'piston (2)',
#  'Martin 4-0-4': 'piston (2)',
#  'Martin M-130': 'piston (4)',
#  'Martin Mars': 'piston (4)',
#  'Martin P5M Marlin': 'piston (2)',
#  'Martin PBM-5 Mariner': 'piston (4)',
#  'MBB HFB-320 Hansa Jet': 'jet (2)',
#  'McDonnell Douglas C-17 Globemaster III': 'jet (4)',
#  'McDonnell Douglas DC-10': 'jet (3)',
#  'McDonnell Douglas DC-8': 'jet (4)',
#  'McDonnell Douglas DC-9-10': 'jet (2)',
#  'McDonnell Douglas DC-9-20': 'jet (2)',
#  'McDonnell Douglas DC-9-30': 'jet (2)',
#  'McDonnell Douglas DC-9-40': 'jet (2)',
#  'McDonnell Douglas DC-9-50': 'jet (2)',
#  'McDonnell Douglas DC-9/MD-80s/MD90/B717': 'jet (2)',
#  'McDonnell Douglas MD-11': 'jet (3)',
#  'McDonnell Douglas MD-80': 'jet (2)',
#  'McDonnell Douglas MD-90': 'jet (2)',
#  'Miles Marathon': 'piston (4)',
#  'Mitsubishi MRJ': 'jet (2)',
#  'Mitsubishi Mu-300 Diamond 1': 'jet (2)',
#  'Morane Saulnier MS.760 Paris': 'jet (2)',
#  'NAL Saras': 'turboprop (2)',
#  'NAMC YS-11': 'turboprop (2)',
#  'Nord 2501 Noratlas': 'piston (2)',
#  'Nord 260': 'turboprop (2)',
#  'Nord 262': 'turboprop (2)',
#  'Northrop YC-125 Raider': 'piston (3)',
#  'Piaggio PD.808': 'jet (2)',
#  'Pilatus PC-24': 'jet (2)',
#  'Piper PA-47 PiperJet': 'jet (1)',
#  'Potez 62': 'piston (2)',
#  'Potez 840': 'turboprop (4)',
#  'Potez-CAMS 161': 'piston (6)',
#  'PTDI N219': 'turboprop (2)',
#  'PZL MD-12': 'piston (4)',
#  'PZL-Mielec M28': 'turboprop (2)',
#  'Raytheon Premier 1': 'jet (2)',
#  'Reims-Cessna F406 Caravan II': 'turboprop (2)',
#  'Rockwell 1121 Jet Commander': 'jet (2)',
#  'Rockwell Sabreliner': 'jet (2)',
#  'Rohrbach Ro X Romar': 'piston (3)',
#  'SAAB 2000': 'turboprop (2)',
#  'SAAB 340': 'turboprop (2)',
#  'SAAB Scandia': 'piston (2)',
#  'Saunders ST-27': 'turboprop (2)',
#  'Savoia-Marchetti S.66': 'piston (3)',
#  'Savoia-Marchetti S.73': 'piston (3)',
#  'Savoia-Marchetti S.74': 'piston (4)',
#  'Savoia-Marchetti SM.75': 'piston (3)',
#  'Savoia-Marchetti SM.95': 'piston (4)',
#  'Scottish Aviation Twin Pioneer': 'piston (2)',
#  'Shijiazhuang Y-5': 'piston (1)',
#  'Shin Meiwa PS-1': 'turboprop (4)',
#  'ShinMaywa US-2': 'turboprop (4)',
#  'Short L.17 Scylla': 'piston (4)',
#  'Short S.17 Kent': 'piston (4)',
#  'Short S.23 Empire': 'piston (4)',
#  'Short S.25 Sandringham/Sunderland': 'piston (4)',
#  'Short S.26 G Class': 'piston (4)',
#  'Short S.45 Solent': 'piston (4)',
#  'Short S.8 Calcutta': 'piston (3)',
#  'Shorts 330': 'turboprop (2)',
#  'Shorts 360': 'turboprop (2)',
#  'Shorts SC.7 Skyvan': 'turboprop (2)',
#  'Sikorsky S.41': 'piston (2)',
#  'Sikorsky S.42': 'piston (4)',
#  'Sikorsky S.43': 'piston (2)',
#  'Sikorsky VS-44': 'piston (4)',
#  'SNCAC NC.211 Cormoran': 'piston (4)',
#  'SNCASE (Lioré et Olivier) H.246': 'piston (4)',
#  'SNCASE SE.161 Languedoc': 'piston (4)',
#  'SNCASE SE.200': 'piston (6)',
#  'SNCASE SE.2010 Armagnac': 'piston (4)',
#  'SNCASO Corse': 'piston (2)',
#  'SNCASO SO.30': 'piston (2)',
#  'Spectrum Aeronautical Spectrum 33': 'jet (2)',
#  'Sud Aviation SE-210 Caravelle': 'jet (2)',
#  'Sukhoi Su-80': 'turboprop (2)',
#  'Sukhoi Superjet 100': 'jet (2)',
#  'Swearingen Merlin IV': 'turboprop (2)',
#  'Swearingen Metro': 'turboprop (2)',
#  'Swearingen Metro / Merlin IV': 'turboprop (2)',
#  'SyberJet SJ30-2': 'jet (2)',
#  'Transall C-160': 'turboprop (2)',
#  'Tupolev ANT-20': 'piston (8)',
#  'Tupolev G-2': 'piston (4)',
#  'Tupolev Tu-104': 'jet (2)',
#  'Tupolev Tu-114': 'turboprop (4)',
#  'Tupolev Tu-124': 'jet (2)',
#  'Tupolev Tu-134': 'jet (2)',
#  'Tupolev Tu-144': 'jet (4)',
#  'Tupolev Tu-154': 'jet (3)',
#  'Tupolev Tu-204': 'jet (2)',
#  'Tupolev Tu-334': 'jet (2)',
#  'VFW-614': 'jet (2)',
#  'Vickers 170 Vanguard': 'piston (2)',
#  'Vickers Valentia': 'piston (2)',
#  'Vickers Valetta': 'piston (2)',
#  'Vickers Vanguard': 'turboprop (4)',
#  'Vickers Varsity': 'piston (2)',
#  'Vickers VC10': 'jet (4)',
#  'Vickers Viking': 'piston (2)',
#  'Vickers Viscount': 'turboprop (4)',
#  'Volpar Turboliner': 'turboprop (2)',
#  'Xian Y-20': 'jet (4)',
#  'Xian Yunshuji Y-7': 'turboprop (2)',
#  'Yakovlev Yak-40': 'jet (3)',
#  'Yakovlev Yak-42': 'jet (3)'}

# %% [markdown]
# We now use a JSON format in order to extract the dictionary to an external text file,<br>
# to have the ability to use it in the next step:

# %%
with open("aircrafts_to_engines.txt", "w") as textfile:
    textfile.write(json.dumps(ae_dict))

# %% [markdown]
# The output file, named <b>"aircrafts_to_engines.txt</b> can be found in our project folder in GitHub
